# %% [markdown]
# ## **Working with Linear Regression**

# %% [markdown]
# ## Step 1: Data Preparation
#
# - Import the required libraries
# - Load the Boston housing data set
# - Prepare the data set

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets

# %%
from sklearn.datasets import fetch_openml

boston = fetch_openml(name='boston', version=1, as_frame=True, parser='auto')
data = boston.data
target = boston.target
feature_names = boston.feature_names

# %% [markdown]
# ## Step 2: Create a DataFrame and Check for Missing Values
#
# - Create a DataFrame using the Boston housing data
# - Display basic statistics
# - Check for missing values

# %%
print(boston.DESCR)
# Out:
# **Author**:
# **Source**: Unknown - Date unknown
# **Please cite**:
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
# Variables in order:
# CRIM     per capita crime rate by town
# ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
# INDUS    proportion of non-retail business acres per town
# CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
# NOX      nitric oxides concentration (parts per 10 million)
# RM       average number of rooms per dwelling
# AGE      proportion of owner-occupied units built prior to 1940
# DIS      weighted distances to five Boston employment centres
# RAD      index of accessibility to radial highways
# TAX      full-value property-tax rate per $10,000
# PTRATIO  pupil-teacher ratio by town
# B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# LSTAT    % lower status of the population
# MEDV     Median value of owner-occupied homes in $1000's
#
#
# Information about the dataset
# CLASSTYPE: numeric
# CLASSINDEX: last
#
# Downloaded from openml.org.

# %%
df = pd.DataFrame(boston.data, columns=boston.feature_names)
df['HousePrice'] = boston.target
df.head()
# Out:
#       CRIM    ZN  INDUS CHAS    NOX     RM   AGE     DIS RAD    TAX  PTRATIO  \
# 0  0.00632  18.0   2.31    0  0.538  6.575  65.2  4.0900   1  296.0     15.3
# 1  0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671   2  242.0     17.8
# 2  0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671   2  242.0     17.8
# 3  0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622   3  222.0     18.7
# 4  0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622   3  222.0     18.7
#
#         B  LSTAT  HousePrice
# 0  396.90   4.98        24.0
# 1  396.90   9.14        21.6
# 2  392.83   4.03        34.7
# 3  394.63   2.94        33.4
# 4  396.90   5.33        36.2

# %% [markdown]
# __Observation__:
#
# - This is the head of the data set.

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS         NOX          RM         AGE  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.554695    6.284634   68.574901
# std      8.601545   23.322453    6.860353    0.115878    0.702617   28.148861
# min      0.006320    0.000000    0.460000    0.385000    3.561000    2.900000
# 25%      0.082045    0.000000    5.190000    0.449000    5.885500   45.025000
# 50%      0.256510    0.000000    9.690000    0.538000    6.208500   77.500000
# 75%      3.677083   12.500000   18.100000    0.624000    6.623500   94.075000
# max     88.976200  100.000000   27.740000    0.871000    8.780000  100.000000
#
#               DIS         TAX     PTRATIO           B       LSTAT  HousePrice
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.795043  408.237154   18.455534  356.674032   12.653063   22.532806
# std      2.105710  168.537116    2.164946   91.294864    7.141062    9.197104
# min      1.129600  187.000000   12.600000    0.320000    1.730000    5.000000
# 25%      2.100175  279.000000   17.400000  375.377500    6.950000   17.025000
# 50%      3.207450  330.000000   19.050000  391.440000   11.360000   21.200000
# 75%      5.188425  666.000000   20.200000  396.225000   16.955000   25.000000
# max     12.126500  711.000000   22.000000  396.900000   37.970000   50.000000

# %% [markdown]
# __Observation__:
# - Here, you can see the statistical analysis of the data set.

# %%
df.isna().sum()
# Out:
# CRIM          0
# ZN            0
# INDUS         0
# CHAS          0
# NOX           0
# RM            0
# AGE           0
# DIS           0
# RAD           0
# TAX           0
# PTRATIO       0
# B             0
# LSTAT         0
# HousePrice    0
# dtype: int64

# %% [markdown]
# __Observation__:
#
# - There are no empty rows in the dataset.

# %% [markdown]
# ## Step 3: Remove Outliers from the HousePrice Column
#
#
# - Use a boxplot to visualize the outliers
# - Remove outliers from the __HousePrice__ column using the 1% and 99% quantiles

# %%
sns.boxplot(df['HousePrice'])
# Out:
# <Axes: >

# %% [markdown]
# __Observation__:
#
# - There are outliers in the data set.

# %%
upper_limit = df['HousePrice'].quantile(0.99)
lower_limit = df['HousePrice'].quantile(0.01)

# %%
x = np.random.randint(0,100,(5,2))
x
# Out:
# array([[61, 61],
#        [73, 66],
#        [35, 39],
#        [60, 72],
#        [90, 38]])

# %%
np.where(x<30,99,x)
# Out:
# array([[61, 61],
#        [73, 66],
#        [35, 39],
#        [60, 72],
#        [90, 38]])

# %%
lower_limit
# Out:
# 7.01

# %%
upper_limit
# Out:
# 50.0

# %%
df['HousePrice'] = np.where(df['HousePrice'] < lower_limit, lower_limit, df['HousePrice'])
df['HousePrice'] = np.where(df['HousePrice'] > upper_limit, upper_limit, df['HousePrice'])

# %%
df
# Out:
#         CRIM    ZN  INDUS CHAS    NOX     RM   AGE     DIS RAD    TAX  \
# 0    0.00632  18.0   2.31    0  0.538  6.575  65.2  4.0900   1  296.0
# 1    0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671   2  242.0
# 2    0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671   2  242.0
# 3    0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622   3  222.0
# 4    0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622   3  222.0
# ..       ...   ...    ...  ...    ...    ...   ...     ...  ..    ...
# 501  0.06263   0.0  11.93    0  0.573  6.593  69.1  2.4786   1  273.0
# 502  0.04527   0.0  11.93    0  0.573  6.120  76.7  2.2875   1  273.0
# 503  0.06076   0.0  11.93    0  0.573  6.976  91.0  2.1675   1  273.0
# 504  0.10959   0.0  11.93    0  0.573  6.794  89.3  2.3889   1  273.0
# 505  0.04741   0.0  11.93    0  0.573  6.030  80.8  2.5050   1  273.0
#
#      PTRATIO       B  LSTAT  HousePrice
# 0       15.3  396.90   4.98        24.0
# 1       17.8  396.90   9.14        21.6
# 2       17.8  392.83   4.03        34.7
# 3       18.7  394.63   2.94        33.4
# 4       18.7  396.90   5.33        36.2
# ..       ...     ...    ...         ...
# 501     21.0  391.99   9.67        22.4
# 502     21.0  396.90   9.08        20.6
# 503     21.0  396.90   5.64        23.9
# 504     21.0  393.45   6.48        22.0
# 505     21.0  396.90   7.88        11.9
#
# [506 rows x 14 columns]

# %% [markdown]
# # Implement the Linear Regression Model

# %%
df.shape
# Out:
# (506, 14)

# %%
# separate features and target

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.drop(columns="HousePrice"), df['HousePrice'],
                                                 test_size=0.2, random_state=0)

# %%
X_train.shape
# Out:
# (404, 13)

# %%
X_test.shape
# Out:
# (102, 13)

# %%
y_train.shape
# Out:
# (404,)

# %%
y_test.shape
# Out:
# (102,)

# %%
from sklearn.linear_model import LinearRegression
linear = LinearRegression()

# %%
linear.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
linear.coef_
# Out:
# array([-1.09309520e-01,  4.47155350e-02,  5.02960365e-03,  2.34255318e+00,
#        -1.60965441e+01,  3.70977894e+00, -3.33833537e-03, -1.38541572e+00,
#         2.41518043e-01, -1.09892919e-02, -1.04660051e+00,  8.36056268e-03,
#        -4.91375461e-01])

# %%
linear.intercept_
# Out:
# 37.99390404879049

# %%
y = "y="
for i,j in zip(X_train.columns,linear.coef_):
    y+= (i+ "*"+str(j)+"+")
y += str(linear.intercept_)

# %%
print(y)
# Out:
# y=CRIM*-0.10930952037389649+ZN*0.04471553502079237+INDUS*0.005029603654599152+CHAS*2.342553177021746+NOX*-16.096544138513188+RM*3.7097789372702366+AGE*-0.003338335369455586+DIS*-1.385415720242657+RAD*0.24151804338467034+TAX*-0.010989291851084625+PTRATIO*-1.0466005055901122+B*0.008360562677098638+LSTAT*-0.4913754610771608+37.99390404879049

# %% [markdown]
# ## Step 4: Test for Linearity of the Model
#
# - Fit the model and display the summary
# - Define functions to calculate residuals and plot actual vs. predicted values
# - Test for linearity

# %%
import statsmodels.api as sm
import numpy as np
import pandas as pd

boston.data = boston.data.apply(pd.to_numeric)

X_constant = sm.add_constant(np.asarray(boston.data))
boston_model = sm.OLS(boston.target, np.asarray(boston.data)).fit()
boston_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   MEDV   R-squared (uncentered):                   0.959
# Model:                            OLS   Adj. R-squared (uncentered):              0.958
# Method:                 Least Squares   F-statistic:                              891.3
# Date:                Sun, 14 Apr 2024   Prob (F-statistic):                        0.00
# Time:                        21:51:43   Log-Likelihood:                         -1523.8
# No. Observations:                 506   AIC:                                      3074.
# Df Residuals:                     493   BIC:                                      3128.
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0929      0.034     -2.699      0.007      -0.161      -0.025
# x2             0.0487      0.014      3.382      0.001       0.020       0.077
# x3            -0.0041      0.064     -0.063      0.950      -0.131       0.123
# x4             2.8540      0.904      3.157      0.002       1.078       4.630
# x5            -2.8684      3.359     -0.854      0.394      -9.468       3.731
# x6             5.9281      0.309     19.178      0.000       5.321       6.535
# x7            -0.0073      0.014     -0.526      0.599      -0.034       0.020
# x8            -0.9685      0.196     -4.951      0.000      -1.353      -0.584
# x9             0.1712      0.067      2.564      0.011       0.040       0.302
# x10           -0.0094      0.004     -2.395      0.017      -0.017      -0.002
# x11           -0.3922      0.110     -3.570      0.000      -0.608      -0.176
# x12            0.0149      0.003      5.528      0.000       0.010       0.020
# x13           -0.4163      0.051     -8.197      0.000      -0.516      -0.317
# ==============================================================================
# Omnibus:                      204.082   Durbin-Watson:                   0.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1374.225
# Skew:                           1.609   Prob(JB):                    3.90e-299
# Kurtosis:                      10.404   Cond. No.                     8.50e+03
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 8.5e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# - Define a function to calculate residual values by taking the actual and predicted values
# - The value of residuals is equal to the difference between the actual and  predicted values.

# %%
def calculate_residuals(model, features, label):
    predictions =  model.predict(features)
    df_results = pd.DataFrame({'Actual' : label, 'Predicted' : predictions})
    df_results['Residuals'] = abs(df_results['Actual']) - abs(df_results['Predicted'])
    return df_results

# %% [markdown]
# - Next, define a function to plot the actual and predicted values using __lmplot__.
# - The orange line will show the fitted line created by the linear regression model.

# %%
def linear_assumptions(model, features, label):
    df_results = calculate_residuals(model, features, label)

    sns.lmplot(x='Actual', y='Predicted', data=df_results, fit_reg=False, height=7)
    line_coords = np.arange(df_results.min().min(), df_results.max().max())
    plt.plot(line_coords, line_coords, color='darkorange', linestyle='--')
    plt.title('Actual vs. Predicted')
    plt.show()

# %% [markdown]
# - Now, run the function __linear_assumptions__ to show the graph with the model as __boston_model__, features as __boston.data__, and label as __boston.taget__ variables as arguments.

# %%
linear_assumptions(boston_model, boston.data, boston.target)

# %% [markdown]
# __Observation__:
#
# - We can observe that the line does not represent all the data points.

# %% [markdown]
# ## Step 5: Check for Multicollinearity
#
# - Let's check the correlation between the variables in the data set.

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_c9d15_row0_col0, #T_c9d15_row1_col1, #T_c9d15_row2_col2, #T_c9d15_row3_col3, #T_c9d15_row4_col4, #T_c9d15_row5_col5, #T_c9d15_row6_col6, #T_c9d15_row7_col7, #T_c9d15_row8_col8, #T_c9d15_row9_col9, #T_c9d15_row10_col10, #T_c9d15_row11_col11, #T_c9d15_row12_col12, #T_c9d15_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c9d15_row0_col1, #T_c9d15_row3_col0 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_c9d15_row0_col2 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_c9d15_row0_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_c9d15_row0_col4 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_c9d15_row0_col5 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_c9d15_row0_col6, #T_c9d15_row1_col13 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_c9d15_row0_col7, #T_c9d15_row11_col4, #T_c9d15_row11_col10 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_c9d15_row0_col8 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_c9d15_row0_col9, #T_c9d15_row2_col8, #T_c9d15_row8_col0 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_c9d15_row0_col10 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_c9d15_row0_col11 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_c9d15_row0_col12 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_c9d15_row0_col13, #T_c9d15_row8_col13, #T_c9d15_row11_col2 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_c9d15_row1_col0 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_c9d15_row1_col2, #T_c9d15_row1_col6, #T_c9d15_row8_col3 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_c9d15_row1_col3 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_c9d15_row1_col4, #T_c9d15_row1_col9 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_c9d15_row1_col5, #T_c9d15_row2_col0 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_c9d15_row1_col7, #T_c9d15_row9_col4, #T_c9d15_row13_col5 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_c9d15_row1_col8 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_c9d15_row1_col10, #T_c9d15_row9_col3, #T_c9d15_row13_col8 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_c9d15_row1_col11 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_c9d15_row1_col12, #T_c9d15_row5_col2, #T_c9d15_row6_col3, #T_c9d15_row10_col11 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_c9d15_row2_col1, #T_c9d15_row7_col3 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_c9d15_row2_col3, #T_c9d15_row8_col1 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_c9d15_row2_col4 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_c9d15_row2_col5, #T_c9d15_row7_col12 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_c9d15_row2_col6 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_c9d15_row2_col7, #T_c9d15_row4_col1, #T_c9d15_row11_col8 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_c9d15_row2_col9 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_c9d15_row2_col10, #T_c9d15_row13_col1 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_c9d15_row2_col11, #T_c9d15_row11_col9, #T_c9d15_row12_col3 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_c9d15_row2_col12, #T_c9d15_row6_col12, #T_c9d15_row12_col6 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_c9d15_row2_col13 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_c9d15_row3_col1 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_c9d15_row3_col2 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_c9d15_row3_col4, #T_c9d15_row10_col0 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_c9d15_row3_col5 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_c9d15_row3_col6 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_c9d15_row3_col7 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_c9d15_row3_col8, #T_c9d15_row3_col9 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_c9d15_row3_col10 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_c9d15_row3_col11 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_c9d15_row3_col12 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_c9d15_row3_col13 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_c9d15_row4_col0 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_c9d15_row4_col2 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_c9d15_row4_col3, #T_c9d15_row5_col3, #T_c9d15_row5_col8 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_c9d15_row4_col5, #T_c9d15_row13_col4 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_c9d15_row4_col6 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_c9d15_row4_col7, #T_c9d15_row6_col1, #T_c9d15_row7_col0, #T_c9d15_row7_col2, #T_c9d15_row7_col4, #T_c9d15_row7_col6, #T_c9d15_row7_col8, #T_c9d15_row7_col9, #T_c9d15_row8_col11, #T_c9d15_row9_col11, #T_c9d15_row10_col3, #T_c9d15_row11_col0, #T_c9d15_row12_col5, #T_c9d15_row12_col13, #T_c9d15_row13_col0, #T_c9d15_row13_col10, #T_c9d15_row13_col12 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_c9d15_row4_col8 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_c9d15_row4_col9 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_c9d15_row4_col10 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_c9d15_row4_col11, #T_c9d15_row13_col9 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_c9d15_row4_col12, #T_c9d15_row8_col2 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_c9d15_row4_col13 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_c9d15_row5_col0, #T_c9d15_row6_col11 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_c9d15_row5_col1 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_c9d15_row5_col4, #T_c9d15_row13_col3 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_c9d15_row5_col6 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_c9d15_row5_col7 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_c9d15_row5_col9, #T_c9d15_row10_col5 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_c9d15_row5_col10, #T_c9d15_row12_col1 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_c9d15_row5_col11 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_c9d15_row5_col12 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_c9d15_row5_col13 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_c9d15_row6_col0 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_c9d15_row6_col2 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_c9d15_row6_col4 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_c9d15_row6_col5 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_c9d15_row6_col7 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_c9d15_row6_col8 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_c9d15_row6_col9 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_c9d15_row6_col10, #T_c9d15_row7_col11 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_c9d15_row6_col13 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_c9d15_row7_col1 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_c9d15_row7_col5 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_c9d15_row7_col10 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_c9d15_row7_col13 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_c9d15_row8_col4 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_c9d15_row8_col5 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_c9d15_row8_col6 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_c9d15_row8_col7, #T_c9d15_row9_col13, #T_c9d15_row12_col7 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_c9d15_row8_col9 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_c9d15_row8_col10 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_c9d15_row8_col12 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_c9d15_row9_col0 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_c9d15_row9_col1 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_c9d15_row9_col2 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_c9d15_row9_col5 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_c9d15_row9_col6 {

# %% [markdown]
# - Calculate the variance inflation factor (VIF) for each feature
# - Import the __variance_inflation_factor__ module from the __statsmodels.stats.outliers_influence__ library
# - Set the features as the DataFrame, except the target variable
# - Assign the __vif_data__ to the feature columns

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
import pandas as pd
import numpy as np

x = df.drop(['HousePrice'], axis=1)
x = x.astype(float)  # Convert the array to float type

vif_data = pd.DataFrame()
vif_data['Features'] = x.columns

vif_data['vif'] = [variance_inflation_factor(x.values, i) for i in range(len(x.columns))]
print(vif_data)
# Out:
#    Features        vif
# 0      CRIM   2.100373
# 1        ZN   2.844013
# 2     INDUS  14.485758
# 3      CHAS   1.152952
# 4       NOX  73.894947
# 5        RM  77.948283
# 6       AGE  21.386850
# 7       DIS  14.699652
# 8       RAD  15.167725
# 9       TAX  61.227274
# 10  PTRATIO  85.029547
# 11        B  20.104943
# 12    LSTAT  11.102025

# %% [markdown]
# __Observation__:
# - From the above output, we can infer that the columns **NOX, RM, AGE,** and **PTRATIO** have higher multicollinearity. Hence, we can drop them.

# %% [markdown]
# ## Step 6: Remove Multicollinear Features and Split the Data set
#
# - Remove highly multicollinear features from the data set

# %%
df1 = df.drop(['NOX', 'RM', 'AGE', 'PTRATIO'], axis = 1)

# %% [markdown]
# - Now, set the feature and target variables.

# %%
x = df1.drop(['HousePrice'], axis =1)
y = df1['HousePrice']

# %% [markdown]
# - Next, split the data into train and test sets.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test  = train_test_split(x, y, random_state=0, test_size=0.25)

# %% [markdown]
# ## Step 7: Fit the Model and Evaluate Performance
#
# - Fit the model using OLS and display the summary.

# %%
X_train = pd.DataFrame(X_train)
y_train = pd.DataFrame(y_train)
X_test = pd.DataFrame(X_test) 

X_train = X_train.apply(pd.to_numeric, errors='coerce')
X_test = X_test.apply(pd.to_numeric, errors='coerce')

X_train = np.asarray(X_train)
y_train = np.asarray(y_train)
X_test = np.asarray(X_test) 

print(X_train.dtype)
print(y_train.dtype)
print(np.isnan(X_train).sum())
print(np.isnan(y_train).sum())

model = sm.OLS(y_train, X_train).fit()

print(model.summary())
# Out:
# float64
# float64
# 0
# 0
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.902
# Model:                            OLS   Adj. R-squared (uncentered):              0.900
# Method:                 Least Squares   F-statistic:                              378.5
# Date:                Sun, 14 Apr 2024   Prob (F-statistic):                   1.20e-180
# Time:                        21:51:43   Log-Likelihood:                         -1308.7
# No. Observations:                 379   AIC:                                      2635.
# Df Residuals:                     370   BIC:                                      2671.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.1194      0.064     -1.867      0.063      -0.245       0.006
# x2             0.0843      0.023      3.648      0.000       0.039       0.130
# x3            -0.0144      0.109     -0.133      0.894      -0.228       0.199
# x4             5.1092      1.633      3.128      0.002       1.898       8.321
# x5             0.2127      0.268      0.795      0.427      -0.313       0.739
# x6            -0.0482      0.119     -0.406      0.685      -0.281       0.185
# x7             0.0175      0.006      2.706      0.007       0.005       0.030
# x8             0.0555      0.004     15.262      0.000       0.048       0.063
# x9            -0.4937      0.073     -6.780      0.000      -0.637      -0.351
# ==============================================================================
# Omnibus:                       57.021   Durbin-Watson:                   1.956
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               79.878
# Skew:                           1.019   Prob(JB):                     4.52e-18
# Kurtosis:                       3.949   Cond. No.                     2.27e+03
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 2.27e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn import linear_model

# %% [markdown]
# - Now, fit the model using linear regression.

# %%
reg = linear_model.LinearRegression()
reg.fit(X_train, y_train)
y_pred_train = reg.predict(X_train)
y_pred_test = reg.predict(X_test)

X_test = pd.DataFrame(X_test)  # Convert X_test to a pandas DataFrame
X_test = X_test.apply(pd.to_numeric, errors='coerce')  # Convert non-numeric values to NaN
X_test = np.asarray(X_test)  # Convert X_test to a numpy array

y_pred_test = reg.predict(X_test)  # Predict using the trained model

# %% [markdown]
# - Evaluate the model using various metrics such as the **r2_score, mean_absolute_error, and mean_squared_error**

# %%
print("R Square: {}".format(r2_score(y_train, y_pred_train)))
print("MAE: {}".format(mean_absolute_error(y_train, y_pred_train)))
print("MSE: {}".format(mean_squared_error(y_train, y_pred_train)))
# Out:
# R Square: 0.6857716700262139
# MAE: 3.766238016784235
# MSE: 26.676235416618063

# %% [markdown]
# __Observation__:
#
# - From the above output, we can observe that the model is a moderate fit for the given data.

# %%
print("R Square: {}".format(r2_score(y_test, y_pred_test)))
print("MAE: {}".format(mean_absolute_error(y_test, y_pred_test)))
print("MSE: {}".format(mean_squared_error(y_test, y_pred_test)))
# Out:
# R Square: 0.5257075212801094
# MAE: 4.179321963752526
# MSE: 38.58065185545441

# %% [markdown]
# __Observation__:
#
# - The model moderately explains the testing data, as indicated by the **R** **Square** value.

# %% [markdown]
# # SGD

# %%
from sklearn.linear_model import SGDRegressor
sgd = SGDRegressor()

sgd.fit(X_train.astype("float"),y_train)

y_pred_test = sgd.predict(X_test.astype("float"))

r2_score(y_test,y_pred_test)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# -5.337643276658504e+26
